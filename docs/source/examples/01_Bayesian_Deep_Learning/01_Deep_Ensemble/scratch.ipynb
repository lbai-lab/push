# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn

# Generate dataset and grid
torch.manual_seed(0)  # Set a seed for reproducibility
X = torch.rand(100, 1) * 0.5
x_grid = torch.linspace(-5, 5, 1000).reshape(-1, 1)

# Define function
def target_toy(x):
    torch.manual_seed(0)  # Reset seed for consistent randomness
    epsilons = torch.randn(3) * 0.02
    return (
        x + 0.3 * torch.sin(2 * torch.pi * (x + epsilons[0])) +
        0.3 * torch.sin(4 * torch.pi * (x + epsilons[1])) + epsilons[2]
    )

# Generate target values
torch.manual_seed(0)  # Reset seed for consistent randomness
Y = torch.stack([target_toy(x) for x in X])

# %%
# Plot the generated data
plt.figure()  # figsize=[12,6], dpi=200)
plt.plot(X, Y, "kx", label="Toy data", alpha=0.8)
# plt.title('Simple 1D example with toy data by Blundell et. al (2015)')
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.xlim(-0.5, 1.0)
plt.ylim(-0.8, 1.6)
plt.legend()
plt.show()

# %%
class GenericNet(nn.Module):
    def __init__(self, input_dim):
        super(GenericNet, self).__init__()
        self.input_dim = input_dim
        
        self.net = nn.Sequential(
            nn.Linear(in_features=input_dim, out_features=16),
            nn.ELU(),
            nn.Linear(in_features=16, out_features=16),
            nn.ELU(),
            nn.Linear(in_features=16, out_features=1)
        )
        # Additional layers can be added here based on the architecture
        # Apply Xavier uniform initialization to the weights
        self.init_weights(self.net)

    def forward(self, x):
        return self.net(x)

    def init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            m.bias.data.fill_(0.01)


class Model(nn.Module):
    def __init__(self, beta):
        super(Model, self).__init__()
        self.prior = GenericNet(input_dim=1)  # Specify the input dimension
        self.trainable = GenericNet(input_dim=1)  # Specify the input dimension
        self.beta = beta

    def forward(self, x):
        x1 = self.prior(x)
        x2 = self.trainable(x)
        return self.beta * x1 + x2

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
# Combine X and Y into a TensorDataset
dataset = TensorDataset(X, Y)

# Create a DataLoader for batch processing during training
batch_size = 100  # Adjust according to your needs
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
import torch
from torch.utils.data import DataLoader
import push.bayes.ensemble

epochs = 3000
betas = [0.001, 5, 50, 100]
lr = 0.03
# seed = 2
# torch.manual_seed(seed)
num_ensembles=9

ensemble_1 = push.bayes.ensemble.train_deep_ensemble(
        train_loader,
        torch.nn.MSELoss(),
        epochs,
        Model, betas[0],
        lr = lr,
        num_devices=2,
        num_ensembles=num_ensembles,
        prior=True,
        random_seed=True
    )
ensemble_2 = push.bayes.ensemble.train_deep_ensemble(
        train_loader,
        torch.nn.MSELoss(),
        epochs,
        Model, betas[1],
        lr = lr,
        num_devices=2,
        num_ensembles=num_ensembles,
        prior=True,
        random_seed=True
    )
ensemble_3 = push.bayes.ensemble.train_deep_ensemble(
        train_loader,
        torch.nn.MSELoss(),
        epochs,
        Model, betas[2],
        lr = lr,
        num_devices=2,
        num_ensembles=num_ensembles,
        prior=True,
        random_seed=True
    )
ensemble_4 = push.bayes.ensemble.train_deep_ensemble(
        train_loader,
        torch.nn.MSELoss(),
        epochs,
        Model, betas[3],
        lr = lr,
        num_devices=2,
        num_ensembles=num_ensembles,
        prior=True,
        random_seed=True
    )
# Out:
# 100%|██████████| 3000/3000 [02:52<00:00, 17.40it/s, loss=tensor(5.3614e-05)]
#  44%|████▍     | 1332/3000 [01:18<01:37, 17.05it/s, loss=tensor(0.0001)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      10 num_ensembles=9
#      12 ensemble_1 = push.bayes.ensemble.train_deep_ensemble(
#      13         train_loader,
#      14         torch.nn.MSELoss(),
#    (...)
#      21         random_seed=True
#      22     )
# ---> 23 ensemble_2 = push.bayes.ensemble.train_deep_ensemble(
#      24         train_loader,
#      25         torch.nn.MSELoss(),
#      26         epochs,
#      27         Model, betas[1],
#      28         lr = lr,
#      29         num_devices=2,
#      30         num_ensembles=num_ensembles,
#      31         prior=True,
#      32         random_seed=True
#      33     )
#      34 ensemble_3 = push.bayes.ensemble.train_deep_ensemble(
#      35         train_loader,
#      36         torch.nn.MSELoss(),
#    (...)
#      43         random_seed=True
#      44     )
#      45 ensemble_4 = push.bayes.ensemble.train_deep_ensemble(
#      46         train_loader,
#      47         torch.nn.MSELoss(),
#    (...)
#      54         random_seed=True
#      55     )
#
# File ~/push/push/bayes/ensemble.py:460, in train_deep_ensemble(dataloader, loss_fn, epochs, nn, lr, num_devices, cache_size, view_size, num_ensembles, prior, random_seed, ensemble_entry, ensemble_state, *args)
#     440 """Train a deep ensemble PusH distribution and return a list of particle parameters.
#     441
#     442 Args:
#    (...)
#     457     List[torch.Tensor]: Returns a list of all particle's parameters.
#     458 """
#     459 ensemble = Ensemble(nn, *args, num_devices=num_devices, cache_size=cache_size, view_size=view_size)
# --> 460 ensemble.bayes_infer(dataloader, epochs, loss_fn=loss_fn, lr=lr, num_ensembles=num_ensembles,
#     461                      ensemble_entry=ensemble_entry, ensemble_state=ensemble_state, prior=prior, random_seed=random_seed)
#     462 return ensemble
#
# File ~/push/push/bayes/ensemble.py:394, in Ensemble.bayes_infer(self, dataloader, epochs, loss_fn, lr, num_ensembles, mk_scheduler, prior, random_seed, ensemble_entry, ensemble_state, f_save)
#     388     pids += [self.push_dist.p_create(mk_optim, mk_scheduler, prior, train_keys[n], device=(n % self.num_devices), receive={
#     389         "ENSEMBLE_STEP": _ensemble_step,
#     390         "ENSEMBLE_PRED": _ensemble_pred,
#     391         "SCHEDULER_STEP": _ensemble_scheduler_step
#     392     }, state={})]
#     393 # 2. Perform independent training
# --> 394 self.push_dist.p_wait([self.push_dist.p_launch(0, "ENSEMBLE_MAIN", dataloader, loss_fn, epochs, bootstrap)])
#     396 if f_save:
#     397     self.push_dist.save()
#
# File ~/push/push/push.py:274, in PusH.p_launch(self, pid_to, msg, sync, *args)
#     272 # Send message
#     273 rank = self._particle_to_rank[pid_to]
# --> 274 self._in_queues[rank].put(ReceiveFuncPDMSG((pid_to, fid), pid_to, msg, args))
#     276 if sync:
#     277     # Synchronize
#     278     y = self._out_queues[rank].get()
#
# File ~/push/push/pqueue.py:31, in SinglePQueue.put(self, msg)
#      29 self._queue += [msg]
#      30 # NOTE: Since put in a multi-processing setting "calls" the function, we have to dispatch here.
# ---> 31 self._nel._dispatch(msg)
#
# File ~/push/push/lib/node_event_loop.py:279, in NodeEventLoop._dispatch(self, msg)
#     277 particle = Particle(self, pid_device, pid, module, state)
#     278 try:
# --> 279     y = fn(particle, *msg.args)
#     280 except Exception as e:
#     281     self.out_queue.put(e)
#
# File ~/push/push/bayes/ensemble.py:132, in _deep_ensemble_main(particle, dataloader, loss_fn, epochs, bootstrap)
#     130             else:
#     131                 for data, label in dataloader:
# --> 132                     particle.send(other_particles[i-1], "ENSEMBLE_STEP", loss_fn, data, label)
#     134         tq.set_postfix({'loss': torch.mean(torch.tensor(losses))})
#     135         # for data, label in dataloader:
#     136         #     loss = particle.step(loss_fn, data, label).wait()
#     137         #     losses += [loss]
#    (...)
#     143
#     144 else:
#
# File ~/push/push/particle.py:72, in Particle.send(self, pid, msg, *args)
#      61 def send(self, pid: int, msg: str, *args: any) -> PFuture:
#      62     """Send a `msg` to `pid` with arguments `*args` from current particle.
#      63
#      64     Args:
#    (...)
#      70         PFuture: Handle to future result.
#      71     """
# ---> 72     return self._node_event_loop.send(self, self.pid, pid, msg, *args)
#
# File ~/push/push/lib/node_event_loop.py:470, in NodeEventLoop.send(self, send_particle, pid_curr, pid, msg_name, *args)
#     467 self._results[fid] = y
#     469 # NOTE: INVARIANT: the current function always has it's module in scope
# --> 470 send_particle.module = self._context_switch_module(pid_curr, msg='send switch back')
#     472 # Return future
#     473 return PFuture(self, pid_curr, pid, fid)
#
# File ~/push/push/lib/node_event_loop.py:137, in NodeEventLoop._context_switch_module(self, pid, pin, msg)
#     134 pid_device = self._particle_to_device[pid]
#     136 # Try read
# --> 137 self._wait_particle_thread(pid)
#     138 module = self.particle_caches[pid_device].try_read(pid, pin=pin, msg=msg)
#     140 # Try reload module
#
# File ~/push/push/lib/node_event_loop.py:120, in NodeEventLoop._wait_particle_thread(self, pid)
#     118 active_pid, active_thread = self._device_to_pthread.pop(pid_device)
#     119 active_pid_device = self._particle_to_device[active_pid]
# --> 120 self.particle_caches[active_pid_device].release(active_pid, active_thread)
#
# File ~/push/push/lib/context_switch.py:215, in ParticleCache.release(self, pid, thread)
#     203 """
#     204 Release a pinned particle.
#     205
#    (...)
#     212
#     213 """
#     214 with self._lock:
# --> 215     thread.join()
#     216     if pid in self._pinned:
#     217         self._pinned.remove(pid)
#
# File ~/anaconda3/envs/push_exp/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/anaconda3/envs/push_exp/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
ensemble_1_outputs = ensemble_1.posterior_pred(x_grid, f_reg=True, mode=["mean", "std", "pred"])
ensemble_2_outputs = ensemble_2.posterior_pred(x_grid, f_reg=True, mode=["mean", "std", "pred"])
ensemble_3_outputs = ensemble_3.posterior_pred(x_grid, f_reg=True, mode=["mean", "std", "pred"])
ensemble_4_outputs = ensemble_4.posterior_pred(x_grid, f_reg=True, mode=["mean", "std", "pred"])

outputs = [ensemble_1_outputs, ensemble_2_outputs, ensemble_3_outputs, ensemble_4_outputs]

# %%
# Plot mean and std for each beta
# fig = plt.figure(figsize=[8, len(betas) * 3], dpi=150)
fig, axs = plt.subplots(nrows=4, ncols=2, sharex=True, sharey=True)
for i, beta in enumerate(betas):
    # Plot predictive mean and std (left graph)
    # plt.subplot(len(betas), 2, 2 * i + 1)
    axs[i, 0].plot(X, Y, "kx", label="Toy data", markersize=1)
    # plt.title(f'Mean and Deviation for beta={beta}', fontsize=12)
    if beta < 1:
        axs[i, 0].text(-0.2, 1.2, r"$\beta$" + f"={beta:.3f}")
        # axs[i,0].set_title(f"beta={beta:.3f}")
    else:
        axs[i, 0].text(-0.2, 1.2, r"$\beta$=" + f"{int(beta)}")
        # axs[i,0].set_title(f"beta={int(beta)}")
    axs[i, 0].set_xlim(-0.5, 1)
    axs[i, 0].set_ylim(-2, 2)
    # plt.legend()
    axs[i, 0].plot(x_grid, outputs[i]["mean"], "r--", linewidth=1)
    axs[i, 0].fill_between(x_grid.reshape(1, -1)[0], (outputs[i]["mean"] - outputs[i]["std"]).squeeze(), (outputs[i]["mean"] + outputs[i]["std"]).squeeze(), alpha=0.5, color="red")
    axs[i, 0].fill_between(
        x_grid.reshape(1, -1)[0], (outputs[i]["mean"] + 2 * outputs[i]["std"]).squeeze(), (outputs[i]["mean"] - 2 * outputs[i]["std"]).squeeze(), alpha=0.2, color="red"
    )

    # Plot means of each net in ensemble (right graph)
    # plt.subplot(len(betas), 2, 2 * i + 2)
    axs[i, 1].plot(X, Y, "kx", label="Toy data", markersize=1)
    # plt.title(f'Samples for beta={beta}', fontsize=12)
    if beta < 1:
        axs[i, 1].text(-0.2, 1.2, r"$\beta$" + f"={beta:.3f}")
        # axs[i,1].set_title(f"beta={beta:.3f}")
    else:
        axs[i, 1].text(-0.2, 1.2, r"$\beta$=" + f"{int(beta)}")
        # axs[i,1].set_title(f"beta={int(beta)}")

    # if is_latexify_enabled():
    #     axs[i, 1].set_xticklabels([-0.5, 0, 0.5, 1])
    axs[i, 1].set_xlim(-0.5, 1)
    axs[i, 1].set_ylim(-1.5, 2)
    # sns.despine()
    # plt.legend()
    for j in range(num_ensembles):
        axs[i, 1].plot(x_grid, torch.tensor([sublist[j] for sublist in outputs[i]["pred"]]), linestyle="--", linewidth=1)


plt.tight_layout()
# if is_latexify_enabled():
#     plt.subplots_adjust(wspace=5.5)
# pml.savefig("randomized_priors_changing_beta")
# plt.savefig("randomized_priors_changing_beta.png")
plt.show()

# %%
# def generate_bootstrap(seed, n_samples):
#     torch.manual_seed(seed)
#     return torch.randint(0, n_samples, (n_samples,), dtype=torch.long)

# def build_bootstrap_datasets(num_ensembles, X, Y, batch_size, shuffle):
#     bootstraps = [generate_bootstrap(42 * i, X.shape[0]) for i in range(1, num_ensembles + 1)]
#     loaders = []
#     for indices in bootstraps:
#         X_b = torch.index_select(X, 0, indices)
#         Y_b = torch.index_select(Y, 0, indices)
#         dataset = TensorDataset(X_b, Y_b)
#         batch_size = 100  # Adjust according to your needs
#         loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
#         loaders.append(loader)
#     return loaders

# n_estimators = 4
# bootstrap_datasets = build_bootstrap_datasets(num_ensembles, X, Y, batch_size, shuffle=True)

# %%
# prior_boot_ensemble = push.bayes.ensemble.train_deep_ensemble(
#         train_loader,
#         torch.nn.MSELoss(),
#         epochs,
#         Model, betas[0],
#         lr = lr,
#         num_devices=2,
#         num_ensembles=num_ensembles,
#         prior=True,
#         random_seed=True
#     )
# prior_no_boot_ensemble = push.bayes.ensemble.train_deep_ensemble(
#         train_loader,
#         torch.nn.MSELoss(),
#         epochs,
#         Model, betas[1],
#         lr = lr,
#         num_devices=2,
#         num_ensembles=num_ensembles,
#         prior=True,
#         random_seed=True
#     )
# noprior_boot_ensemble = push.bayes.ensemble.train_deep_ensemble(
#         train_loader,
#         torch.nn.MSELoss(),
#         epochs,
#         Model, betas[2],
#         lr = lr,
#         num_devices=2,
#         num_ensembles=num_ensembles,
#         prior=True,
#         random_seed=True
#     )
# noprior_noboot_ensemble = push.bayes.ensemble.train_deep_ensemble(
#         train_loader,
#         torch.nn.MSELoss(),
#         epochs,
#         Model, betas[3],
#         lr = lr,
#         num_devices=2,
#         num_ensembles=num_ensembles,
#         prior=True,
#         random_seed=True
#     )
# Out:
#   1%|          | 28/3000 [00:01<02:38, 18.75it/s, loss=tensor(0.0297)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 prior_boot_ensemble = push.bayes.ensemble.train_deep_ensemble(
#       2         train_loader,
#       3         torch.nn.MSELoss(),
#       4         epochs,
#       5         Model, betas[0],
#       6         lr = lr,
#       7         num_devices=2,
#       8         num_ensembles=num_ensembles,
#       9         prior=True,
#      10         random_seed=True
#      11     )
#      12 prior_no_boot_ensemble = push.bayes.ensemble.train_deep_ensemble(
#      13         train_loader,
#      14         torch.nn.MSELoss(),
#    (...)
#      21         random_seed=True
#      22     )
#      23 noprior_boot_ensemble = push.bayes.ensemble.train_deep_ensemble(
#      24         train_loader,
#      25         torch.nn.MSELoss(),
#    (...)
#      32         random_seed=True
#      33     )
#
# File ~/push/push/bayes/ensemble.py:406, in train_deep_ensemble(dataloader, loss_fn, epochs, nn, lr, num_devices, cache_size, view_size, num_ensembles, prior, random_seed, ensemble_entry, ensemble_state, *args)
#     397 def train_deep_ensemble(dataloader: Callable, loss_fn: Callable, epochs: int,
#     398                         nn: Callable, *args, lr: float = 0.01, num_devices: int = 1, cache_size: int = 4, view_size: int = 4,
#     399                         num_ensembles: int = 2, prior = False, random_seed = False,
#     400                         ensemble_entry = _deep_ensemble_main, ensemble_state={}) -> List[torch.Tensor]:
#     401     """Train a deep ensemble PusH distribution and return a list of particle parameters.
#     402
#     403     Args:
#     404         dataloader (Callable): Dataloader.
#     405         loss_fn (Callable): Loss function to be used during training.
# --> 406         epochs (int, optional): Number of epochs to train for.
#     407         nn (Callable): The base model to be ensembled and trained.
#     408         *args (any): Any arguments needed for the model's initialization.
#     409         num_devices (int, optional): The desired number of gpu devices to be utilized during training. Defaults to 1.
#     410         cache_size (int, optional): The desired size of cache allocated to storing particles. Defaults to 4.
#     411         view_size (int, optional): The number of other particle's parameters that can be seen by a particle on a single GPU. Defaults to 4.
#     412         num_ensembles (int, optional): The number of models to be ensembled. Defaults to 2.
#     413         mk_optim (any, optional): Returns an optimizer. Defaults to mk_optim.
#     414         ensemble_entry (function, optional): Training loop for deep ensemble. Defaults to _deep_ensemble_main.
#     415         ensemble_state (dict, optional): a dictionary to store state variables for ensembled models. i.e. in swag we need to know how
#     416            how many swag epochs have passed to properly calculate a running average of model weights. Defaults to {}.
#     417     Returns:
#     418         List[torch.Tensor]: Returns a list of all particle's parameters.
#     419     """
#     420     ensemble = Ensemble(nn, *args, num_devices=num_devices, cache_size=cache_size, view_size=view_size)
#     421     ensemble.bayes_infer(dataloader, epochs, loss_fn=loss_fn, lr=lr, num_ensembles=num_ensembles,
#     422                          ensemble_entry=ensemble_entry, ensemble_state=ensemble_state, prior=prior, random_seed=random_seed)
#
# File ~/push/push/bayes/ensemble.py:340, in bayes_infer(self, dataloader, epochs, loss_fn, lr, num_ensembles, mk_scheduler, prior, random_seed, ensemble_entry, ensemble_state, f_save)
#     338     train_keys = torch.randint(0, int(1e9), (num_ensembles,), dtype=torch.int64).tolist()
#     339 else:
# --> 340     train_keys = [-1] * num_ensembles
#     341 # 1. Create particles
#     342 pids = [
#     343     self.push_dist.p_create(mk_optim, mk_scheduler, prior, train_keys[0], device=(0 % self.num_devices), receive={
#     344         "ENSEMBLE_MAIN": ensemble_entry,
#     345         "LEADER_PRED_DL": _leader_pred_dl,
#     346         "LEADER_PRED": _leader_pred,
#     347     }, state=ensemble_state)]
#
# File ~/push/push/push.py:274, in PusH.p_launch(self, pid_to, msg, sync, *args)
#     272 # Send message
#     273 rank = self._particle_to_rank[pid_to]
# --> 274 self._in_queues[rank].put(ReceiveFuncPDMSG((pid_to, fid), pid_to, msg, args))
#     276 if sync:
#     277     # Synchronize
#     278     y = self._out_queues[rank].get()
#
# File ~/push/push/pqueue.py:31, in SinglePQueue.put(self, msg)
#      29 self._queue += [msg]
#      30 # NOTE: Since put in a multi-processing setting "calls" the function, we have to dispatch here.
# ---> 31 self._nel._dispatch(msg)
#
# File ~/push/push/lib/node_event_loop.py:279, in NodeEventLoop._dispatch(self, msg)
#     277 particle = Particle(self, pid_device, pid, module, state)
#     278 try:
# --> 279     y = fn(particle, *msg.args)
#     280 except Exception as e:
#     281     self.out_queue.put(e)
#
# File ~/push/push/bayes/ensemble.py:100, in _deep_ensemble_main(particle, dataloader, loss_fn, epochs)
#      98     losses += [loss]
#      99     for pid in other_particles:
# --> 100         particle.send(pid, "ENSEMBLE_STEP", loss_fn, data, label)
#     101 for pid in other_particles:
#     102         particle.send(pid, "SCHEDULER_STEP")
#
# File ~/push/push/particle.py:72, in Particle.send(self, pid, msg, *args)
#      61 def send(self, pid: int, msg: str, *args: any) -> PFuture:
#      62     """Send a `msg` to `pid` with arguments `*args` from current particle.
#      63
#      64     Args:
#    (...)
#      70         PFuture: Handle to future result.
#      71     """
# ---> 72     return self._node_event_loop.send(self, self.pid, pid, msg, *args)
#
# File ~/push/push/lib/node_event_loop.py:462, in NodeEventLoop.send(self, send_particle, pid_curr, pid, msg_name, *args)
#     460 args2 = [detach_to_device(pid_device, arg) for arg in args]
#     461 try:
# --> 462     y = fn(particle, *args2)
#     463 except Exception as e:
#     464     self.out_queue.put(e)
#
# File ~/push/push/bayes/ensemble.py:127, in _ensemble_step(particle, loss_fn, data, label, *args)
#     123 def _ensemble_step(particle: Particle, loss_fn: Callable, data, label, *args) -> None:
#     124     """
#     125     Perform a single step of ensemble training for a particle.
#     126
# --> 127     Args:
#     128         particle (Particle): The particle to perform the ensemble step.
#     129         loss_fn (Callable): The loss function used for training.
#     130         data: The input data for training.
#     131         label: The labels corresponding to the input data.
#     132         *args: Additional arguments for the ensemble step.
#     133
#     134     Returns:
#     135         None
#     136
#     137     Note:
#     138         This function performs a single step of ensemble training for the specified particle. It calls the
#     139         particle's step method with the provided loss function, input data, and labels. Additional arguments
#     140         can be passed for customization during training.
#     141     """
#     142     particle.step(loss_fn, data, label, *args)
#
# File ~/push/push/particle.py:137, in Particle.step(self, loss_fn, data, label, *args)
#     135 label = detach_to_device(self.device, label)
#     136 args = [detach_to_device(self.device, arg) for arg in args]
# --> 137 return self._node_event_loop.step(self.pid, loss_fn, data, label, *args)
#
# File ~/push/push/lib/node_event_loop.py:674, in NodeEventLoop.step(self, pid, loss_fn, data, label, *args)
#     672 pid_device = self._particle_to_device[pid]
#     673 self._device_to_pthread[pid_device] = (pid, t)
# --> 674 t.start()
#     676 # Return future
#     677 return PFuture(self, pid, pid, fid, t=t)
#
# File ~/anaconda3/envs/push_exp/lib/python3.10/threading.py:940, in Thread.start(self)
#     938         del _limbo[self]
#     939     raise
# --> 940 self._started.wait()
#
# File ~/anaconda3/envs/push_exp/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/envs/push_exp/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
# Out:
# 1
